# %% [markdown]
# # **IMPORTING**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df=pd.read_csv('covid_19_clean_complete.csv')
df.head(15)
# Out:
#                   Province/State       Country/Region       Lat        Long  \
# 0                            NaN          Afghanistan  33.93911   67.709953
# 1                            NaN              Albania  41.15330   20.168300
# 2                            NaN              Algeria  28.03390    1.659600
# 3                            NaN              Andorra  42.50630    1.521800
# 4                            NaN               Angola -11.20270   17.873900
# 5                            NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                            NaN            Argentina -38.41610  -63.616700
# 7                            NaN              Armenia  40.06910   45.038200
# 8   Australian Capital Territory            Australia -35.47350  149.012400
# 9                New South Wales            Australia -33.86880  151.209300
# 10            Northern Territory            Australia -12.46340  130.845600
# 11                    Queensland            Australia -27.46980  153.025100
# 12               South Australia            Australia -34.92850  138.600700
# 13                      Tasmania            Australia -42.88210  147.327200
# 14                      Victoria            Australia -37.81360  144.963100
#
#           Date  Confirmed  Deaths  Recovered  Active             WHO Region
# 0   2020-01-22          0       0          0     0.0  Eastern Mediterranean
# 1   2020-01-22          0       0          0     0.0                 Europe
# 2   2020-01-22          0       0          0     0.0                 Africa
# 3   2020-01-22          0       0          0     0.0                 Europe
# 4   2020-01-22          0       0          0     0.0                 Africa
# 5   2020-01-22          0       0          0     0.0               Americas
# 6   2020-01-22          0       0          0     0.0               Americas
# 7   2020-01-22          0       0          0     0.0                 Europe
# 8   2020-01-22          0       0          0     0.0        Western Pacific
# 9   2020-01-22          0       0          0     0.0        Western Pacific
# 10  2020-01-22          0       0          0     0.0        Western Pacific
# 11  2020-01-22          0       0          0     0.0        Western Pacific
# 12  2020-01-22          0       0          0     0.0        Western Pacific
# 13  2020-01-22          0       0          0     0.0        Western Pacific
# 14  2020-01-22          0       0          0     0.0        Western Pacific

# %%
df.shape
# Out:
# (31891, 10)

# %% [markdown]
# CONTAINS 49068 RECORDS WUTH 10 ATTRIBUTES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31891 entries, 0 to 31890
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  9535 non-null   object
#  1   Country/Region  31891 non-null  object
#  2   Lat             31891 non-null  float64
#  3   Long            31891 non-null  float64
#  4   Date            31891 non-null  object
#  5   Confirmed       31891 non-null  int64
#  6   Deaths          31891 non-null  int64
#  7   Recovered       31891 non-null  int64
#  8   Active          31890 non-null  float64
#  9   WHO Region      31890 non-null  object
# dtypes: float64(3), int64(3), object(4)
# memory usage: 2.4+ MB

# %%
df.isnull().sum()
# Out:
# Province/State    22356
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                1
# WHO Region            1
# dtype: int64

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed        Deaths      Recovered  \
# count  31891.000000  31891.000000  3.189100e+04  31891.000000   31891.000000
# mean      21.427318     23.514347  5.275882e+03    350.848358    1608.296573
# std       24.962510     70.463208  4.622751e+04   3204.611095   11395.550624
# min      -51.796300   -135.000000  0.000000e+00      0.000000       0.000000
# 25%        7.873054    -15.310100  0.000000e+00      0.000000       0.000000
# 50%       23.634500     21.745300  2.400000e+01      0.000000       1.000000
# 75%       41.204380     80.771797  4.840000e+02      6.000000     107.000000
# max       71.706900    178.065000  1.608653e+06  97025.000000  350135.000000
#
#              Active
# count  3.189000e+04
# mean   3.316841e+03
# std    3.486419e+04
# min   -6.000000e+00
# 25%    0.000000e+00
# 50%    8.000000e+00
# 75%    2.070000e+02
# max    1.190338e+06

# %%
total_confirmed = df.groupby("Country/Region")["Confirmed"].sum().sort_values(ascending=False).head(20).reset_index()

# %%
x_column = 'Confirmed'
y_column = 'Country/Region'

plt.figure(figsize=(10, 6))

sns.barplot(x=x_column, y=y_column, data=total_confirmed)

plt.xlabel('Total Confirmed Cases', fontsize=14)
plt.ylabel('Countries', fontsize=12)
plt.title('Top 20 Countries by Total Cases', fontsize=15)

plt.show()

# %% [markdown]
# # *USA Has the highest number of covid confirmed case....followed by BRAZIL which is more than 2 times of BRAZIL*

# %%
total_confirmed
# Out:
#     Country/Region  Confirmed
# 0               US   50639625
# 1            Italy   10976449
# 2            Spain   10947970
# 3            China    8537725
# 4   United Kingdom    8361837
# 5          Germany    8324143
# 6           France    8016218
# 7           Russia    6062910
# 8           Brazil    5572078
# 9           Turkey    5239662
# 10            Iran    5232408
# 11          Canada    2635608
# 12         Belgium    2309067
# 13           India    2111338
# 14            Peru    2035643
# 15     Netherlands    1892807
# 16     Switzerland    1589908
# 17           Chile    1254774
# 18    Saudi Arabia    1231243
# 19        Portugal    1189047

# %% [markdown]
# **Descriptive statistics**

# %%
total_death = df.groupby("Country/Region")["Deaths"].sum().sort_values(ascending=False).head(20).reset_index()

# %%
x_column = 'Deaths'
y_column = 'Country/Region'

plt.figure(figsize=(10, 6))

sns.barplot(x=x_column, y=y_column, data=total_death)

plt.xlabel('Total death', fontsize=14)
plt.ylabel('Countries', fontsize=12)
plt.title('Top 20 Countries with Highest Total Deaths', fontsize=15)

plt.show()

# %% [markdown]
# # **Death due to covid**
# # *Reported highest number in USA*

# %%
total_death
# Out:
#     Country/Region   Deaths
# 0               US  2875676
# 1            Italy  1436924
# 2            Spain  1190629
# 3   United Kingdom  1182228
# 4           France  1096127
# 5           Brazil   367548
# 6            China   366111
# 7          Belgium   334776
# 8             Iran   323225
# 9          Germany   286441
# 10     Netherlands   220827
# 11          Canada   159802
# 12          Turkey   135081
# 13          Sweden   113135
# 14          Mexico   107906
# 15     Switzerland    79155
# 16           India    67571
# 17         Ecuador    60648
# 18            Peru    57309
# 19          Russia    56389

# %%
total_recover = df.groupby("Country/Region")["Recovered"].sum().sort_values(ascending=False).head(20).reset_index()

# %%
x_column = 'Recovered'
y_column = 'Country/Region'

plt.figure(figsize=(10, 6))

sns.barplot(x=x_column, y=y_column, data=total_recover)

plt.xlabel('Total recover', fontsize=14)
plt.ylabel('Countries', fontsize=12)
plt.title('Top 20 Countries with the Most Recoveries', fontsize=15)

plt.show()

# %% [markdown]
# # *Number of Recovered Patients is higher in USA AND BRAZIL*

# %%
total_recover
# Out:
#    Country/Region  Recovered
# 0              US    6936644
# 1           China    6313232
# 2         Germany    5459735
# 3           Spain    5168767
# 4           Italy    3788857
# 5            Iran    3546238
# 6          Turkey    2417972
# 7          France    2259494
# 8          Brazil    2204406
# 9          Russia    1115261
# 10    Switzerland    1032783
# 11           Peru     678618
# 12          India     666481
# 13         Mexico     656208
# 14        Austria     569530
# 15        Belgium     541535
# 16    South Korea     495471
# 17        Ireland     487633
# 18          Chile     470775
# 19   Saudi Arabia     410870

# %%
total_active = df.groupby("Country/Region")["Active"].sum().sort_values(ascending=False).head(20).reset_index()

# %%
x_column = 'Active'
y_column = 'Country/Region'

plt.figure(figsize=(10, 6))  # Set the figure size as per your preference

sns.barplot(x=x_column, y=y_column, data=total_active)

plt.xlabel('Total active', fontsize=14)
plt.ylabel('Countries', fontsize=12)
plt.title('Top 20 Countries with the Highest Active Cases', fontsize=15)
plt.show()

# %%
total_active
# Out:
#     Country/Region      Active
# 0               US  40827305.0
# 1   United Kingdom   7140402.0
# 2            Italy   5750668.0
# 3           Russia   4891260.0
# 4           France   4660597.0
# 5            Spain   4588574.0
# 6           Brazil   3000124.0
# 7           Turkey   2686609.0
# 8          Germany   2577967.0
# 9           Canada   2475806.0
# 10           China   1858382.0
# 11     Netherlands   1666828.0
# 12         Belgium   1432756.0
# 13           India   1377286.0
# 14            Iran   1362945.0
# 15            Peru   1299716.0
# 16        Portugal   1048673.0
# 17          Sweden    903994.0
# 18         Ecuador    869267.0
# 19    Saudi Arabia    812101.0

# %%
fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Confirmed')

fig.update_layout(width = 700,
                  height = 600,
                  title = 'Total Confirmed',
                  title_x=0.5)

fig.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9a7ea3ab4f76> in <cell line: 1>()
# ----> 1 fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Confirmed')
#       2
#       3 fig.update_layout(width = 700,
#       4                   height = 600,
#       5                   title = 'Total Confirmed',
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2003     args = build_dataframe(args, constructor)
#    2004     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 2005         args = process_dataframe_hierarchy(args)
#    2006     if constructor in [go.Pie]:
#    2007         args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_dataframe_hierarchy(args)
#    1550     df = args["data_frame"]
#    1551     path = args["path"][::-1]
# -> 1552     _check_dataframe_all_leaves(df[path[::-1]])
#    1553     discrete_color = False
#    1554
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in _check_dataframe_all_leaves(df)
#    1529         i = np.nonzero(row.values)[0][0]
#    1530         if not row[i:].all():
# -> 1531             raise ValueError(
#    1532                 "None entries cannot have not-None children",
#    1533                 df_sorted.iloc[null_row_index],
#
# ValueError: ('None entries cannot have not-None children', WHO Region          nan
# Country/Region    China
# Name: 31890, dtype: object)

# %%
fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Deaths')

fig.update_layout(width = 700,
                  height = 600,
                  title = 'Total Deaths',
                  title_x=0.5)

fig.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-957e609c5434> in <cell line: 1>()
# ----> 1 fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Deaths')
#       2
#       3 fig.update_layout(width = 700,
#       4                   height = 600,
#       5                   title = 'Total Deaths',
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2003     args = build_dataframe(args, constructor)
#    2004     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 2005         args = process_dataframe_hierarchy(args)
#    2006     if constructor in [go.Pie]:
#    2007         args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_dataframe_hierarchy(args)
#    1550     df = args["data_frame"]
#    1551     path = args["path"][::-1]
# -> 1552     _check_dataframe_all_leaves(df[path[::-1]])
#    1553     discrete_color = False
#    1554
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in _check_dataframe_all_leaves(df)
#    1529         i = np.nonzero(row.values)[0][0]
#    1530         if not row[i:].all():
# -> 1531             raise ValueError(
#    1532                 "None entries cannot have not-None children",
#    1533                 df_sorted.iloc[null_row_index],
#
# ValueError: ('None entries cannot have not-None children', WHO Region          nan
# Country/Region    China
# Name: 31890, dtype: object)

# %%
fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Recovered')

fig.update_layout(width = 700,
                  height = 600,
                  title = 'Total Recovered',
                  title_x=0.5)

fig.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-ce1b23f10c0c> in <cell line: 1>()
# ----> 1 fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Recovered')
#       2
#       3 fig.update_layout(width = 700,
#       4                   height = 600,
#       5                   title = 'Total Recovered',
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2003     args = build_dataframe(args, constructor)
#    2004     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 2005         args = process_dataframe_hierarchy(args)
#    2006     if constructor in [go.Pie]:
#    2007         args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_dataframe_hierarchy(args)
#    1550     df = args["data_frame"]
#    1551     path = args["path"][::-1]
# -> 1552     _check_dataframe_all_leaves(df[path[::-1]])
#    1553     discrete_color = False
#    1554
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in _check_dataframe_all_leaves(df)
#    1529         i = np.nonzero(row.values)[0][0]
#    1530         if not row[i:].all():
# -> 1531             raise ValueError(
#    1532                 "None entries cannot have not-None children",
#    1533                 df_sorted.iloc[null_row_index],
#
# ValueError: ('None entries cannot have not-None children', WHO Region          nan
# Country/Region    China
# Name: 31890, dtype: object)

# %%
fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Active')

fig.update_layout(width = 700,
                  height = 600,
                  title = 'Total Active',
                  title_x=0.5)

fig.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-9037680870be> in <cell line: 1>()
# ----> 1 fig = px.sunburst(df, path=['WHO Region', 'Country/Region'], values='Active')
#       2
#       3 fig.update_layout(width = 700,
#       4                   height = 600,
#       5                   title = 'Total Active',
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_chart_types.py in sunburst(data_frame, names, values, parents, path, ids, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1539     if path is not None and branchvalues is None:
#    1540         branchvalues = "total"
# -> 1541     return make_figure(
#    1542         args=locals(),
#    1543         constructor=go.Sunburst,
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2003     args = build_dataframe(args, constructor)
#    2004     if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
# -> 2005         args = process_dataframe_hierarchy(args)
#    2006     if constructor in [go.Pie]:
#    2007         args, trace_patch = process_dataframe_pie(args, trace_patch)
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in process_dataframe_hierarchy(args)
#    1550     df = args["data_frame"]
#    1551     path = args["path"][::-1]
# -> 1552     _check_dataframe_all_leaves(df[path[::-1]])
#    1553     discrete_color = False
#    1554
#
# /usr/local/lib/python3.10/dist-packages/plotly/express/_core.py in _check_dataframe_all_leaves(df)
#    1529         i = np.nonzero(row.values)[0][0]
#    1530         if not row[i:].all():
# -> 1531             raise ValueError(
#    1532                 "None entries cannot have not-None children",
#    1533                 df_sorted.iloc[null_row_index],
#
# ValueError: ('None entries cannot have not-None children', WHO Region          nan
# Country/Region    China
# Name: 31890, dtype: object)
